# %%
import astropy.coordinates as coord
import astropy.units as u
from astropy.io import ascii
from astropy.table import Table
from astropy.coordinates import SkyCoord 
import numpy as np
from astropy.io import fits
import matplotlib.pyplot as plt
import seaborn as sn
sn.set_context("poster")
import glob
from spectra_lamost import spectra

# %%
fitsfile_="../Lamost-spectra/*fits"
file_list = glob.glob(fitsfile_)

# %%
for file_ in file_list:
    spectra(file_)
# Out:
# Nome file: ../Lamost-spectra/spec-55923-F5592304_sp08-167 => RA and DEC: 145.912262 30.629816
# Nome file: ../Lamost-spectra/spec-56199-EG010159N023133V_1_sp16-239 => RA and DEC: 14.47259 4.68021
# Nome file: ../Lamost-spectra/spec-56355-HD084033N331638F01_sp10-139 => RA and DEC: 127.171339 33.267199
# Nome file: ../Lamost-spectra/spec-56373-GAC118N39V1_sp06-060 => RA and DEC: 121.86746 39.051687
# Nome file: ../Lamost-spectra/spec-57030-HD090427N432630V01_sp08-215 => RA and DEC: 137.275742 42.067606
# Nome file: ../Lamost-spectra/spec-57387-EG010159N023133M01_sp08-188 => RA and DEC: 16.029158 1.236962
# Nome file: ../Lamost-spectra/spec-57731-HD082137N335612M02_sp08-047 => RA and DEC: 126.593392 33.837064
# Nome file: ../Lamost-spectra/spec-57865-HD145048N572439M01_sp07-136 => RA and DEC: 226.27876 56.264546
# Nome file: ../Lamost-spectra/spec-58164-HD084033N331638B02_sp10-094 => RA and DEC: 127.530014 32.67134
# Nome file: ../Lamost-spectra/spec-58190-HD081308N293923V01_sp13-057 => RA and DEC: 125.994771 29.98705

# %% [markdown]
# # 1 sigma away

# %%
fitsfile_1="../Lamost-spectra-1sigma/*fits"
file_list1 = glob.glob(fitsfile_1)

# %%
for file_1 in file_list1:
    spectra(file_1)
# Out:
# Nome file: ../Lamost-spectra-1sigma/spec-56096-VB3_235N52_V2_sp05-041 => RA and DEC: 235.17046 51.391476
# Nome file: ../Lamost-spectra-1sigma/spec-56322-HD084649N380231B01_sp15-231 => RA and DEC: 130.939791 38.809289
# Nome file: ../Lamost-spectra-1sigma/spec-56667-HD085234N322826M_sp09-204 => RA and DEC: 134.08973 33.018569
# Nome file: ../Lamost-spectra-1sigma/spec-57031-EG024121N042539B01_sp15-187 => RA and DEC: 40.203897 5.361326
# Nome file: ../Lamost-spectra-1sigma/spec-57041-HD093821N401423M01_sp03-228 => RA and DEC: 142.93103 39.895007
# Nome file: ../Lamost-spectra-1sigma/spec-57308-EG000023N024031M01_sp15-101 => RA and DEC: 0.154359 3.462497
# Nome file: ../Lamost-spectra-1sigma/spec-57387-EG010159N023133M01_sp05-073 => RA and DEC: 14.941289 1.71929
# Nome file: ../Lamost-spectra-1sigma/spec-57399-HD095221N375452M01_sp11-087 => RA and DEC: 147.72873 39.657568
# Nome file: ../Lamost-spectra-1sigma/spec-57428-HD091118N401801M01_sp07-207 => RA and DEC: 139.4508 38.324376
# Nome file: ../Lamost-spectra-1sigma/spec-57521-HD161547N531412M01_sp05-127 => RA and DEC: 243.992775 52.250349
# Nome file: ../Lamost-spectra-1sigma/spec-57754-HD090143N355133M01_sp04-185 => RA and DEC: 135.08245 35.626014
# Nome file: ../Lamost-spectra-1sigma/spec-57865-HD145048N572439M01_sp06-181 => RA and DEC: 226.11029 56.772637
